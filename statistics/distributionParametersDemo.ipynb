# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/FDSfE_FBianco/blob/main/statistics/distributionParametersDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # demonstration of distributions changing as the parameters change

# %%
#forward compatibility between python2 and python3
from __future__ import print_function,division
#plotting imports
import pylab as pl
import matplotlib 
from matplotlib import animation
from IPython.display import HTML
# %pylab inline
pl.style.use("https://raw.githubusercontent.com/fedhere/DSPS_2021/master/fbb.mplstyle")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#stats imports
import scipy as sp
from scipy import stats

# %% [markdown]
# # Binomial distribution:
#
# $k=\textstyle {n \choose k}\, p^k (1-p)^{n-k}$
#
# parameters:
#     - n: number of tries
#     - p: probability of success at each try
# defines the probability of having N "successes" in a series of n independent identical success/failure experiment. The case of n=1 and p=0.5 is describe a fair coin toss.
#
# mean: np
#
# variance: np*(1-p)

# %%
Ndistribs = 20 #number of distributions
ssize = 1000 #sample size

#binomial distribution parameters n,p
n = 20 # n parameter
ps = np.linspace(0, 1.0, n) # p parameter

t = np.linspace(0, n, n+1).astype(int) # x axis
y = np.zeros((Ndistribs, ssize)) #container for the distributions
ls = np.zeros((Ndistribs, len(t))) #container for gaussians corresponding to the distribs

#loop to generate a distribution for each p value
for i,j in enumerate(ps):
    # binomial
    y[i] = sp.stats.binom.rvs(n=n, p=j, size=ssize)
    # gaussian with same mean
    ls[i] = sp.stats.binom.pmf(t, n=n, p=j)
    
#prepare figure
fig, ax = pl.subplots();
ax.axis([-20, 35, 0, 0.4]);

# get and plot histogram of initial distributions
y0 = np.histogram(y[0], bins=t, density=1)[0]
n, bins, patches = plt.hist(y0, bins=t, density=1, 
                            facecolor='SteelBlue', alpha=0.75);
#plot Gaussians
l,= ax.plot(t, ls[i]);

#add label
texts = ax.text(0.70, 0.9,  'p = %.2f'%ps[0], transform=ax.transAxes, 
               fontsize=20)

#line at 0
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
#axis labels
ax.set_title("Binomial")
ax.set_ylabel("probability of N successes")
ax.set_xlabel("N")

#animation function
def animate(i):
    ''' matplotlib animation call
    i: loop iterator
    returns the patches
    '''
    n, _ = np.histogram(y[i], bins=t, density=1)
    for rect, h in zip(patches, n):
        #regenerate histogram
        rect.set_height(h)
    #regenerate gaussian line
    l.set_data(t, ls[i])
    #regenerate label
    texts.set_text('p = %.2f'%ps[i])
    return patches

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y));
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img4882d8aeace148b38b23d1bfa8eaa057">
#     <br>
#     <input id="_anim_slider4882d8aeace148b38b23d1bfa8eaa057" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim4882d8aeace148b38b23d1bfa8eaa057.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim4882d8aeace148b38b23d1bfa8eaa057.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select4882d8aeace148b38b23d1bfa8eaa057" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4882d8aeace148b38b23d1bfa8eaa057";
#     var slider_id = "_anim_slider4882d8aeace148b38b23d1bfa8eaa057";
#     var loop_select_id = "_anim_loop_select4882d8aeace148b38b23d1bfa8eaa057";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt
# 53NxcUGXLl3w7bff4vr165p2QRCwdetWAMCgQYP0cq3aVPXo/tpT279/P/Ly8gx+fSJjYQ+MJOGX\
# X37BF198AQAoLy9HWloa9u/fjyZNmmDGjBl6u054eDimT5+O0NBQrWn0ycnJGD58

# %% [markdown]
# # Poisson distribution:
# $k=\frac{\lambda^k}{k!} e^{-\lambda}$
#
# parameters:
#     - lambda: number of tries
# A discrete distribution that expresses the probability of a number of events
# occurring in a fixed period of time if these events occur with a known average rate
# and independently of the time since the last event. More here http://individual.utoronto.ca/zheli/poisson.pdf
#
# mean: lambda
#
# variance: lambda

# %%
Ndistribs = 20 #number of distributions

#Poisson distribution parameters lambda
n = 20 # n parameter
lambdas = np.linspace(0, Ndistribs-1, Ndistribs).astype(int)# lambda parameter

t = np.linspace(0, n*2, n*2+1).astype(int) # x axis
y = np.zeros((Ndistribs, ssize)) #container for the distributions
ls = np.zeros((Ndistribs, len(t))) #container for gaussians corresponding to the distribs


#loop to generate a distribution for each p value
for i,j in enumerate(lambdas):
    #print(mus[i])
    y[i] = sp.stats.poisson.rvs(size=ssize, mu=j)
    ls[i] = sp.stats.poisson.pmf(t, mu=j)
    #pl.figure()
    #pl.hist(y[i])
    
#prepare figure
fig, ax = pl.subplots();
ax.axis([-n, 35, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = plt.hist(y0, bins, density=1, 
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t, ls[i])
texts = ax.text(0.50, 0.9,  'lambdas = %d'%lambdas[0], transform=ax.transAxes, 
               fontsize=20)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Poisson")
ax.set_ylabel("probability of N")
ax.set_xlabel("N")

def animate(i):    
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    l.set_data(t, ls[i])
    texts.set_text('lambdas = %d'%lambdas[i])
    return patches

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img991e2ccc822c41ebbf2aff3b03b0cfe3">
#     <br>
#     <input id="_anim_slider991e2ccc822c41ebbf2aff3b03b0cfe3" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim991e2ccc822c41ebbf2aff3b03b0cfe3.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim991e2ccc822c41ebbf2aff3b03b0cfe3.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select991e2ccc822c41ebbf2aff3b03b0cfe3" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img991e2ccc822c41ebbf2aff3b03b0cfe3";
#     var slider_id = "_anim_slider991e2ccc822c41ebbf2aff3b03b0cfe3";
#     var loop_select_id = "_anim_loop_select991e2ccc822c41ebbf2aff3b03b0cfe3";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3XlcVOX+B/DPjAOCwIC4MCoJqGVq\
# bmiJmMJPE6+aIqCGEUQpmLnlklq5XVsskOSaooKoUKbmUohUiqRk7rvkcjMJlF1kGUBZhPn94WVq\
# mkGRRsY55/N+ve7NOec5D9/DAN95nvM9z5EUFxerQEREZGSkhg6AiIioIZjAiIjIKDGBERGRUWIC\
# IyIio8QERkRERokJjIiIjBITGBERGSUmMCIiMkpMYEREZJSYwIiIyCgxgRERkVFiAiMiIqPEBEZE\
# $x= \frac{1}{\sigma\sqrt{2\pi}}\, e^{-\frac{(x - \mu)^2}{2 \sigma^2}}$
#
# parameters:
#     - mu: mean
#     - sigma: standard deviation
# It relates to the Central Limit Theorem:
# (Under some conditions which include finite variance) the averages of samples
# of random variables independently drawn from _any_ distributions
# converge in distribution to the normal, i.e.,
# they become normally distributed with mean equal to the expected value and
# sdtandard deviation equal to the square root of the mean.
#
# Also referred to Normal if mean is 0 and Standard Normal if mean is 0 and standard deviation is 1
#
# mean: mu
#
# variance: sigma^2

# %%
Ndistribs = 21
nminmax = 35
t = np.linspace(-nminmax, nminmax, nminmax+1).astype(int)
y = np.zeros((Ndistribs, ssize))
ls = np.zeros((Ndistribs, len(t)))
sigs = np.linspace(1, Ndistribs, Ndistribs).astype(int) # parameter variance 
mu = 10 # parameter mean

for i,j in enumerate(sigs):
    #print(mus[i])
    y[i] = sp.stats.norm.rvs(size=ssize, loc=mu, scale=j)
    ls[i] = sp.stats.norm.pdf(t, loc=mu, scale=j)
    #pl.figure()
    #pl.hist(y[i])
    
fig, ax = pl.subplots()
ax.axis([-20, 20, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = plt.hist(y0, bins, density=1, 
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t, ls[i])
texts = ax.text(0.70, 0.9,  'sig = %d'%sigs[0], transform=ax.transAxes, 
               fontsize=20)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Gaussian")
ax.set_ylabel("probability of x")
ax.set_xlabel("x")

def animate(i):    
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    l.set_data(t, ls[i])
    texts.set_text('sig = %d'%sigs[i])
    return patches
print(r"changing mu")
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))
HTML(ani.to_jshtml())
# Out:
# changing mu
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img4e7c3cfe7f2745a39ddc65e8c4d58eb9">
#     <br>
#     <input id="_anim_slider4e7c3cfe7f2745a39ddc65e8c4d58eb9" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim4e7c3cfe7f2745a39ddc65e8c4d58eb9.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select4e7c3cfe7f2745a39ddc65e8c4d58eb9" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4e7c3cfe7f2745a39ddc65e8c4d58eb9";
#     var slider_id = "_anim_slider4e7c3cfe7f2745a39ddc65e8c4d58eb9";
#     var loop_select_id = "_anim_loop_select4e7c3cfe7f2745a39ddc65e8c4d58eb9";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3XtcVGX+B/DPGWaYAYcB8QIqCmjl\
# mqmFN9RaL/20m4ZiZWZS/lJ3TdG8Vpupm+UNSXLNC2gWlmUqK5rtrkgr7nrB1CxS+6UiKCp44TIw\
# MgPMnN8fOKMjV3WYM2f8vF8vX6/mnOec850J5svznOd8H6GoqEgEERGRzCikDoCIiOhuMIEREZEs\
# MYEREZEsMYEREZEsMYEREZEsMYEREZEsMYEREZEsMYEREZEsMYEREZEsMYEREZEsMYEREZEsMYER\
 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = pl.hist(y0, bins, density=1, 
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t, ls[i])
texts = ax.text(0.70, 0.9,  'mu = %d'%mus[0], transform=ax.transAxes, 
               fontsize=20)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Gaussian")
ax.set_ylabel("probability of x")
ax.set_xlabel("x")

def animate(i):    
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    texts.set_text('mu = %d'%mus[i])
    l.set_data(t, ls[i])
    return patches

print(r"changing mu")
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))
HTML(ani.to_jshtml())
# Out:
# changing mu
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img1803885b22534cfa9a688d0d0912f292">
#     <br>
#     <input id="_anim_slider1803885b22534cfa9a688d0d0912f292" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim1803885b22534cfa9a688d0d0912f292.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim1803885b22534cfa9a688d0d0912f292.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select1803885b22534cfa9a688d0d0912f292" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1803885b22534cfa9a688d0d0912f292";
#     var slider_id = "_anim_slider1803885b22534cfa9a688d0d0912f292";
#     var loop_select_id = "_anim_loop_select1803885b22534cfa9a688d0d0912f292";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3XlcVPX+x/HXDDPsIOICKAloZWku\
# 4a4VlmmLKYqWuaHe1JupWWouv9yudltc0szc0CxMzUyvWnpvoSYWbriQiloqgoKCCzsyA8zM7w9i\
# cgQVFTjM8Hk+Hjx0vmeZ9/HgfOac8z3fo8rIyDAhhBBCWBm10gGEEEKI+yEFTAghhFWSAiaEEMIq\
# SQETQghhlaSACSGEsEpSwIQQQlglKWBCCCGskhQwIYQQVkkKmBBCCKskBUwIIYRVkgImhBDCKkkB\
# E0IIYZWkgAkhhLBKUsCEEEJYJSlgQliRS5cu0apVK5YvX650FCEUp1E6gBDlRa/Xs3XrVnbt2sXZ\
# s2fJysrCycmJhx56iFatWtGtWzf8/f2VjimEuE8qeaClsEWJiYmMHTuW8+fPExgYSNu2balRowa5\
# ubn8+eef7Nmzh8zMTH744Qdq166tdNxSM5lM5OXlYWdnh0Yj3z9F1Sb/A4TN0el0vPvuuyQmJjJ7\
# 9myeffbZYvPo9XrWrl2LSqVSIOH9U6lUODg4KB1DiEpBCpiwOVu2bCE+Pp4hQ4aUWLwAHBwcGDJk\
# iEXb1atX+eabb4iOjiY5ORm9Xk/dunXp2rUrAwYMwM7Ozjzv8uXLCQsLY8uWLdSpU8diPd27d8fH\
# x4dly5aZ23777TfCw8OJi4tDp9Ph4eHB448/zqhRo/Dz8wMgOTmZ5cuXEx0dzfXr13F1dcXX15eQ\
# kBBeeeUVoPAaWHBwMMOGDWP48OHm9W/YsIHIyEji4uJIS0ujWrVqtGrVihEjRhTL16pVK7p27UpI\
# SAiLFi3i1KlTODg40LFjR8aOHYuzs/N9/KsLUfGkgAmbs3PnTgCCg4PvabkzZ86we/duOnbsSN26\
# dSkoKGDfvn0sWrSIpKQk/u///u++8hw+fJhx48bRoEEDBg8ejJubG1evXuXgwYMkJibi5+dHQUEB\
# o0aN4urVq/Tu3Zt69eqRnZ3NmTNniImJMRew2/nmm29o0qQJffr0wd3dnXPnzrFlyxYOHTrEunXr\
# 8PDwsJj/zz//ZOzYsbzyyiu8+OKLHD58mC1btqBSqXj//ffvazuFqGhSwITNiYuLw8XFhbp161q0\
# GwwGsrKyLNocHR1xdHQEIDAwkM2bN1ucVuzXrx/Tpk1jy5YtDB8+nJo1a95znj179mA0Glm0aBGe\
# np7m9qFDh5r/fv78eRISEhg9ejShoaH3/B7ffvstTk5OFm3PPPMMI0eOZOvWrcXWefbsWb788kue\
# eOIJAEJCQsjJyeGHH37g3XfflaMwYRWkG72wOdnZ2bi4uBRrP3/+PJ07d7b42bBhg3m6o6OjuXjl\
# 5+eTkZFBeno6bdu2xWg0cvLkyfvK4+rqCsCuXbsoKCi44zyHDh0iNTX1nt+jqHgZjUays7NJT0/n\
# 0UcfxdXVlRMnThSbv0mTJubiVaRly5YYDAYuXbp0z+8vhBLkCEzYHFdXV3Jycoq1161bl0WLFgGF\
# pws/++wzi+kFBQV8/fXXbN++nYsXL2IyWXbQvfXorbReffVVIiMj+eSTT1i0aBHNmjWjXbt2vPDC\
# C1SvXh0AHx8f/vGPf/DVV1/x0ksv8eijj9KqVSs6depE48aN7/oe0dHRrFixgtjYWPR6/V1z33p0\
# ClCtWjUAMjIy7mczhahwUsCEzalfvz5Hjx4lKSnJ4oPaycmJNm3aAJTYBX3BggWsX7+ezp07M2TI\
# EKpXr45Go+GPP/7g888/x2g0mue9U+9Fg8Fg8drDw4Ovv/6amJgYDhw4wNGjR5k/fz7Lly9nwYIF\
# NG3aFIARI0bQrVs3oqKiiImJYcuWLaxevZrQ0FBGjx592/eLjY1l9OjR+Pr6MnLk

# %% [markdown]
# # Chi Squared
#
# $x=\frac{1}{2^{\frac{k}{2}}\Gamma\left(\frac{k}{2}\right)}\\; x^{\frac{k}{2}-1} e^{-\frac{x}{2}}$
#
# parameters:
#     - k: degrees of freedom
# the distribution of a sum of the squares of k independent standard normal random variables. The most common distribution in Null Hypothesis Rejection Testing
#
# mean: k
#
# variance: 2k

# %%
lambdas = np.linspace(1, 20, 20).astype(int)
for i,j in enumerate(lambdas):
    #print(mus[i])
    y[i] = sp.stats.chi2.rvs(size=ssize, df=j)
    ls[i] = sp.stats.norm.pdf(t, loc=j, scale=np.sqrt(2 * lambdas[i]))
    #pl.figure()
    #pl.hist(y[i])
fig, ax = pl.subplots()
ax.axis([-20, 35, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = pl.hist(y0, bins, density=1, 
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t, ls[i])
texts = ax.text(0.60, 0.9,  'lambda = %d'%lambdas[0], transform=ax.transAxes, 
               fontsize=20)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)

def animate(i):    
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    texts.set_text('lambda = %d'%lambdas[i])
    l.set_data(t, ls[i])
    return patches

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(lambdas))
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc864b5deac8c485ea79323264b09d743">
#     <br>
#     <input id="_anim_sliderc864b5deac8c485ea79323264b09d743" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc864b5deac8c485ea79323264b09d743.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="
# BfPn3JzOdr+AuvecmJioynXbQrEAi4mJ8RuLqqiogMPhwIABAy55fEZGBv71r3/hlVde8RvrioiI\
# QJ8+ffzO7/m66f7UOYTJTjjl0FbtK4c3/pIjOfm4mShYKDYGNmrUKOTl5fn0wnJychAeHo64uLiL\
# Hvv666/j/fffxzPPPINhw4Y1u09CQgJ27twJl8vlc/4+ffpg0KBBytwECSVUdsABBhhRZ6VYgE2Z\
# MgWhoaFYuHAh9u/fj+zsbGRlZWH69Ok+kzsmT56MFStWeL/++OOPsXbtWowfPx69evVCQUGB94/n\
# mSwAzJgxA6dPn8ayZctw8OBBbNq0CdnZ2UhLS2v2HbDu3bsrdWvC6GwvdIfJTrhDurRy58bH0JJD\
# /ADrbJ9zZ7tfoHPec1soOga2du1apKenY8GCBTAajZg2bRpmz57ts5/L5fLpReXl5QEAPvroI3z0\
# 0Uc++y5duhQTJ04EAPzsZz/DmjVrsGrVKsyfPx9XXHEF/uu//qvFD7qzDfoCQEpK

# %% [markdown]
# # Uniform

# %%
t = np.linspace(-Ndistribs, Ndistribs, Ndistribs*2+1).astype(int)
lambdas = np.linspace(1, Ndistribs, Ndistribs).astype(int)
center = 0
for i,j in enumerate(lambdas):
    #print(mus[i])
    y[i] = sp.stats.uniform.rvs(size=ssize, loc=center, scale=j)
fig, ax = pl.subplots()
ax.axis([-20, 35, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = pl.hist(y0, bins, density=1, 
                            facecolor='SteelBlue', alpha=0.75);
texts = ax.text(0.60, 0.9,  'scale = %d'%lambdas[0], transform=ax.transAxes, 
               fontsize=20)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)

def animate(i):    
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    texts.set_text('scale = %d'%lambdas[i])
    l.set_data(t, ls[i])
    return patches

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img96308bb7daea4218bc0b75041f21c2ee">
#     <br>
#     <input id="_anim_slider96308bb7daea4218bc0b75041f21c2ee" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim96308bb7daea4218bc0b75041f21c2ee.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim96308bb7daea4218bc0b75041f21c2ee.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select96308bb7daea4218bc0b75041f21c2ee" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img96308bb7daea4218bc0b75041f21c2ee";
#     var slider_id = "_anim_slider96308bb7daea4218bc0b75041f21c2ee";
#     var loop_select_id = "_anim_loop_select96308bb7daea4218bc0b75041f21c2ee";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3XtYlFXiB/DvcMdmRqQURIuhi+YF\
# NbS4adCNLq6isJlkkK7AxiJaef+toqvtWiB52R5M0CxcvISSl+wiUlCBeCOCvGw+IQiISMowQM7I\
# ZX5/+DDbNIikr+KZ+X6eZ59n58w5Z87pRb6873nfM7L6+no9iIiIBGPV3QMgIiK6EQwwIiISEgOM\
