# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/FDSfE_FBianco/blob/main/CodeExamples/video_analysis_inclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
videos = pd.read_csv("https://github.com/fedhere/FDSfE_FBianco/blob/main/data/USyoutubes.csv?raw=true")

# %%
videos.shape
# Out:
# (40949, 10)

# %%
videos.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
videos.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                   Nickelback Lyrics: Real or Fake?
# 4      17.14.11                           I Dare You: GOING BALD!?
#
#            channel_title  category_id              publish_time  \
# 0           CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1        LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2           Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3  Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4               nigahiga           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# ...

# %%
videos.columns
# Out:
# Index(['trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count'],
#       dtype='object')

# %%
videos[['views', 'likes', 'dislikes', 'comment_count']].corr()
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.849177  0.472213       0.617621
# likes          0.849177  1.000000  0.447186       0.803057
# dislikes       0.472213  0.447186  1.000000       0.700184
# comment_count  0.617621  0.803057  0.700184       1.000000

# %%
import pylab as pl

# %%
pl.imshow(videos[['views', 'likes', 'dislikes', 'comment_count']].corr(),
          clim=(-1,1), cmap="RdBu")
pl.xticks([0, 1, 2, 3 ], ['views', 'likes', 'dislikes', 'comment_count'], 
          rotation= 45)
pl.yticks([0, 1, 2, 3 ], ['views', 'likes', 'dislikes', 'comment_count'], 
          rotation= 45)
pl.colorbar();

# %%
videos[videos["likes"] == videos["likes"].max()]
# Out:
#       trending_date                                title channel_title  \
# 38273      18.01.06  BTS (방탄소년단) 'FAKE LOVE' Official MV       ibighit
#
#        category_id              publish_time  \
# 38273           10  2018-05-18T09:00:02.000Z
#
#                                                     tags      views    likes  \
# 38273  BIGHIT|"빅히트"|"방탄소년단"|"BTS"|"BANGTAN"|"방탄"|"FAK...  123010920  5613827
#
#        dislikes  comment_count
# 38273    206892        1228655

# %%
videos.groupby("channel_title").max().sort_values(by="likes", ascending=False)
# Out:
#                      trending_date  \
# channel_title
# ibighit                   18.31.05
# ChildishGambinoVEVO       18.31.05
# ArianaGrandeVevo          18.31.05
# YouTube Spotlight         18.14.06
# Marvel Entertainment      18.31.03
# ...                            ...
# Rob Andretti              17.22.11
# Slooh                     18.06.02
# Caravan Carolyn           18.31.01
# Snapchat                  17.30.11
# PK Inventor               18.12.01
#
#                                                                   title  \
# channel_title
# ibighit                                      j-hope 'Daydream (백일몽)' MV
# ChildishGambinoVEVO   Childish Gambino - This Is America (Official V...
# ArianaGrandeVevo      Ariana Grande - No Tears Left To Cry (Live On ...
# YouTube Spotlight     YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# Marvel Entertainment  Where Were Ant-Man and the Wasp? | New Trailer...
# ...
